# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

#Find the releative path of Lib folder
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import PyBEM2D as BEMpy

# %%
BEM_Case1=BEMpy.BEM2D()

#1.Build Mesh-#Anti-clock wise for internal domain
Boundary_vert=[(0.0, 0.0), (1.5, 0.0), (2.25, 0.75),(2.25,2.25),
                       (1.25, 2.25), (1.25, 1.25),(1.0,1.0),(0.0,1.0)]  #bottom
element_esize=0.4

BEM_Case1.set_Mesh(Boundary_vert,[],[],element_esize,[],Type="Quad")
BEM_Case1.plot_Mesh()
#BEM_Case1.Mesh.print_debug()

#2.Set Boundary condition
bc0=[(7,100),(3,100),(1,10)]
#bc1=[(5,-10),(15,-10)]
BEM_Case1.set_BoundaryCondition(DirichletBC=bc0)#,RobinBC=bc1)
#bc_func=[(1,DirichletBC_func)]
#BEM_Case1.set_BoundaryCondition(DirichletBC=bc_func,mode='func',update=1)#,RobinBC=bc1)


#3.Set Domain Properties - permeability tensor
k11=1
k12=0
k22=1
k_tensor=[k11,k12,k22]
BEM_Case1.SetProps(k_tensor)
# Out:
# [Mesh] Genetrated...
# [Mesh] Discontinous Element used
# [Mesh] Number of boundary elements:24(Total) 24(Edge) 0(Trace)
# [Mesh] Number of Nodes:72(Total) 72(Edge) 0(Trace) 0(Source)
# [Boundary Condition] BCs set up
# [Boundary Condition] Dirichlet BC @ [(7, 100), (3, 100), (1, 10)]

# %%
puv=BEM_Case1.Solve()
xx=BEM_Case1.PostProcess.plot_Solution(resolution=25)
#BEM_Case1.PostProcess.print_Solution()
#Lshape_domain()
# Out:
# [Solution] #DOFs= 72
# [Visulization] Plotting Solution

# %%
BEM_Case1.get_Solution((0.5,0.5))
# Out:
# (77.38629955793446, 45.226406419881364, -1.8960401039463024)

# %%
xx=BEM_Case1.PostProcess.plot_SolutionBD()

# %%
BEM_Case1.PostProcess.print_Solution()
# Out:
# [Mesh] State
# Number of boundary elements:24
# Edge Num.:8
# # Neumann-1   Dirichlet-0
# (E)Pts	P	Q	U	V
# (1)1	97.13	0.00	-46.05	-0.10
# (1)2	91.36	0.00	-46.20	-0.06
# (1)3	85.57	0.00	-46.49	-0.05
# (2)4	79.73	0.00	-46.98	-0.10
# (2)5	73.82	0.00	-47.74	-0.06
# (2)6	67.78	0.00	-48.90	-0.04
# (3)7	61.57	0.00	-50.66	-0.22
# (3)8	55.08	0.00	-53.31	-0.12
# (3)9	48.18	0.00	-57.38	-0.33
# (4)10	40.63	0.00	-63.92	-1.51
# (4)11	31.99	0.00	-75.72	-0.52
# (4)12	21.00	0.00	-106.88	5.21
# (5)13	10.00	-131.32	-97.23	72.75
# (5)14	10.00	-80.95	-54.16	61.20
# (5)15	10.00	-69.97	-53.26	46.16
# (6)16	10.00	-64.79	-46.02	46.53
# (6)17	10.00	-64.07	-45.27	45.27
# (6)18	10.00	-64.79	-46.53	46.02
# (7)19	10.00	-69.97	-46.16	53.26
# (7)20	10.00	-80.95	-61.20	54.16
# (7)21	10.00	-131.32	-72.75	97.23
# (8)22	21.00	0.00	-5.21	106.88
# (8)23	31.99	0.00	0.52	75.72
# (8)24	40.63	0.00	1.51	63.92
# (9)25	48.18	0.00	0.33	57.38
# (9)26	55.08	0.00	0.12	53.31
# (9)27	61.57	0.00	0.22	50.66
# (10)28	67.78	0.00	0.04	48.90
# (10)29	73.82	0.00	0.06	47.74
# (10)30	79.73	0.00	0.10	46.98
# (11)31	85.57	0.00	0.05	46.49
# (11)32	91.36	0.00	0.06	46.20
# (11)33	97.13	0.00	0.10	46.05
# (12)34	100.00	45.94	0.01	46.04
# (12)35	100.00	45.90	-0.01	45.95
# (12)36	100.00	45.72	0.01	45.77
# (13)37	100.00	45.48	0.00	45.53
# (13)38	100.00	45.20	-0.00	45.25
# (13)39	100.00	44.92	0.00	44.97
# (14)40	100.00	44.67	-0.00	44.72
# (14)41	100.00	44.48	0.00	44.53
# (14)42	100.00	44.34	-0.02	44.42
# (15)43	97.54	0.00	-0.04	44.38
# (15)44	92.61	0.00	-0.04	44.29
# (15)45	87.70	0.00	-0.04	44.08
# (16)46	82.82	0.00	-0.00	43.73
# (16)47	77.99	0.00	-0.02	43.19
# (16)48	73.23	0.00	-0.06	42.41
# (17)49	68.57	0.00	-0.02	41.33
# (17)50	64.06	0.00	-0.07	39.92
# (17)51	59.69	0.00	0.03	39.14
# (18)52	55.36	0.00	12.80	14.48
# (18)53	54.31	0.00	0.10	-0.10
# (18)54	55.36	0.00	-14.48	-12.80
# (19)55	59.69	0.00	-39.14	-0.03
# (19)56	64.06	0.00	-39.92	0.07
# (19)57	68.57	0.00	-41.33	0.02
# (20)58	73.23	0.00	-42.41	0.06
# (20)59	77.99	0.00	-43.19	0.02
# (20)60	82.82	0.00	-43.73	0.00
# (21)61	87.70	0.00	-44.08	0.04
# (21)62	92.61	0.00	-44.29	0.04
# (21)63	97.54	0.00	-44.38	0.04
# (22)64	100.00	44.34	-44.42	0.02
# (22)65	100.00	44.48	-44.53	-0.00
# (22)66	100.00	44.67	-44.72	0.00
# (23)67	100.00	44.92	-44.97	-0.00
# (23)68	100.00	45.20	-45.25	0.00
# (23)69	100.00	45.48	-45.53	-0.00
# (24)70	100.00	45.72	-45.77	-0.01
# (24)71	100.00	45.90	-45.95	0.01
# (24)72	100.00	45.94	-46.04	-0.01
# Unit Boundary Flux 3.072532814303333
# Trace Num.:0
# Unit Trace Flux 0.0
# Source Num.:0
# Mass Balance= 3.072532814303333 3.072532814303333
